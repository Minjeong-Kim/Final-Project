# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_raw = pd.read_csv('C://workspaces//AI//Final_PJT//final pjt//covid.csv',dtype={'id':str})
df_raw.head()
# Out:
#        id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0  16169f    2             1  04-05-2020    02-05-2020  9999-99-99       97
# 1  1009bf    2             1  19-03-2020    17-03-2020  9999-99-99       97
# 2  167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 3  0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 4  0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
#
#    pneumonia  age  pregnancy  ...  inmsupr  hypertension  other_disease  \
# 0          2   27         97  ...        2             2              2
# 1          2   24         97  ...        2             2              2
# 2          2   54          2  ...        2             2              2
# 3          1   30         97  ...        2             2              2
# 4          2   60          2  ...        2             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# 0               2        2              2        2                    2
# 1               2        2              2        2                   99
# 2               2        1              2        2                   99
# 3               2        2              2        2                   99
# 4               1        2              2        2                   99
#
#    covid_res  icu
# 0          1   97
# 1          1   97
# 2          1    2
# 3          1    2
# 4          1    2
#
# [5 rows x 23 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 566602 entries, 0 to 566601
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   566602 non-null  object
#  1   sex                  566602 non-null  int64
#  2   patient_type         566602 non-null  int64
#  3   entry_date           566602 non-null  object
#  4   date_symptoms        566602 non-null  object
#  5   date_died            566602 non-null  object
#  6   intubed              566602 non-null  int64
#  7   pneumonia            566602 non-null  int64
#  8   age                  566602 non-null  int64
#  9   pregnancy            566602 non-null  int64
#  10  diabetes             566602 non-null  int64
#  11  copd                 566602 non-null  int64
#  12  asthma               566602 non-null  int64
#  13  inmsupr              566602 non-null  int64
#  14  hypertension         566602 non-null  int64
#  15  other_disease        566602 non-null  int64
#  16  cardiovascular       566602 non-null  int64
#  17  obesity              566602 non-null  int64
#  18  renal_chronic        566602 non-null  int64
#  19  tobacco              566602 non-null  int64
#  20  contact_other_covid  566602 non-null  int64
#  21  covid_res            566602 non-null  int64
#  22  icu                  566602 non-null  int64
# dtypes: int64(19), object(4)
# memory usage: 99.4+ MB

# %% [markdown]
# ### Data Preprocessing
#
# #### patient_type=1인 사람 제거
#
# - patient_type=1 이면 99% 생존  -> 1인경우는 무조건 생존으로 나올 가능성이 높음. 모델링에 적절 X
# - patient_type=2 이면 50% 생존

# %%
df1 = df_raw[df_raw.patient_type != 1] 
df1['patient_type'].head(20)
# Out:
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 9     2
# 10    2
# 12    2
# 21    2
# 30    2
# 31    2
# 33    2
# 36    2
# 40    2
# 41    2
# 43    2
# 45    2
# 46    2
# 47    2
# 48    2
# Name: patient_type, dtype: int64

# %% [markdown]
# #### 두번 이상 방문한 사람 특성 확인 후 삭제

# %%
# ID 별 방문횟수 CNT
df1['id'] = df1['id'].astype(str)
df1_sub = df1.copy()
df1_sub['visit'] = 1

VISIT_CNT = df1_sub.pivot_table(index = ['id'], values = ['visit'], aggfunc=np.sum)
VISIT_CNT2 = VISIT_CNT[VISIT_CNT.visit != 1] ; VISIT_CNT2 # 두 번 이상 방문한사람
# Out:
# C:\ProgramData\Anaconda3\envs\py37_tf2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           visit
# id
# 0.00E+00     38
# 1.00E+47      2
# 1.00E+53      2
# 1.00E+84      2
# 1.00E+87      2
# ...         ...
# 7.00E+01      2
# 7.00E+02      2
# 7.00E+58      2
# 8.00E+41      2
# 8.60E+10      3
#
# [203 rows x 1 columns]

# %%
PERSON_BY_VISIT = VISIT_CNT2.groupby(['visit']).size(); PERSON_BY_VISIT
# Out:
# visit
# 2     155
# 3      42
# 4       5
# 38      1
# dtype: int64

# %% [markdown]
# - 두 번 이상 방문한 사람이 203명
# - 근데 id = 0.00E+00 인 사람은 38번 카운팅되서 이 id인사람 삭제 id가 너무 작은 수여서 csv로 저장될때 그냥 0으로 저장됨
# - 두번 이상 방문한 사람 모두 소수점 저장될 때 E 표기법으로 저장되어서 동일한 사람처럼 보이지만 성별이 바뀌는 것으로 보아 동일한 사람이 아닌데 동일한 사람처럼 저장된 것임
# - 그래서 2번 이상 방문한 것으로 counting 되는 사람의 row 모두 지워야 함

# %%
df2 = pd.merge(df1, VISIT_CNT, on = ['id'])

df2 = df2[df2.visit == 1] # 두 번 이상 방문한 사람 삭제
df2[df2.visit != 1] # 잘 삭제됬는지 확인 -> OK!
# Out:
# Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
#  #### 남성에서 임신여부 변수 97:해당없음 -> 2: 아니오 로 변경하기!

# %%
df2['pregnancy'] = df2['pregnancy'].apply(lambda x : 2 if x == 97 else x)

# %%
df2[df2.sex == 2] # 남성 -> 임신변수 모두 2로 변경됨 확인
# Out:
#               id  sex  patient_type  entry_date date_symptoms   date_died  \
# 1         0b5948    2             2  17-04-2020    10-04-2020  9999-99-99
# 3         1beec8    2             2  16-04-2020    16-04-2020  29-04-2020
# 4       1.75E+56    2             2  22-04-2020    13-04-2020  9999-99-99
# 7         126f5c    2             2  02-05-2020    02-05-2020  9999-99-99
# 11        0d968b    2             2  24-04-2020    21-04-2020  9999-99-99
# ...          ...  ...           ...         ...           ...         ...
# 121905    1c5d42    2             2  13-06-2020    13-06-2020  9999-99-99
# 121907    0f6881    2             2  21-06-2020    17-06-2020  9999-99-99
# 121908    093a47    2             2  02-05-2020    02-05-2020  9999-99-99
# 121909    067bbd    2             2  07-06-2020    24-05-2020  9999-99-99
# 121910  5.60E+40    2             2  08-05-2020    08-05-2020  13-05-2020
#
#         intubed  pneumonia  age  pregnancy  ...  hypertension  other_disease  \
# 1             2          1   30          2  ...             2              2
# 3             2          1   47          2  ...             2              2
# 4             2          2   63          2  ...             1              2
# 7             2          2   28          2  ...             2              2
# 11            2          2   56          2  ...             2              2
# ...         ...        ...  ...        ...  ...           ...            ...
# 121905        1          2   40          2  ...             2              1
# 121907        2          2   76          2  ...             1              2
# 121908        2          1   45          2  ...             2              2
# 121909        1          1   68          2  ...             1              2
# 121910        1          1   48          2  ...             1              2
#
#         cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# 1                    2        2              2        2                   99
# 3                    2        2              2        2                   99
# 4                    2        2              2        2                   99
# 7                    2        2              2        2                   99
# 11                   2        2              2        2                   99
# ...                ...      ...            ...      ...                  ...
# 121905               2        2              2        2                   99
# 121907               2        2              2        2                   99
# 121908               2        2              2        2                   99
# 121909               2        1              2        2                    2
# 121910               2        2              2        2                    2
#
#         covid_res  icu  visit
# 1               1    2      1
# 3               1    1      1
# 4               1    2      1
# 7               1    2      1
# 11              1    2      1
# ...           ...  ...    ...
# 121905          3    1      1
# 121907          3    2      1
# 121908          3    2      1
# 121909          3    1      1
# 121910          3    1      1
#
# [72775 rows x 24 columns]

# %% [markdown]
# #### 모든 변수 98 -> 99로 변경

# %%
df3 = df2.copy()
for i in ['pneumonia', 'diabetes', 'copd', 'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular', 'obesity', 'renal_chronic', 'tobacco']:
    df3[i] = df3[i].apply(lambda x : 99 if x == 98 else x)

# %%
check = []
for i in ['pneumonia', 'diabetes', 'copd', 'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular', 'obesity', 'renal_chronic', 'tobacco']:
    check.append(df3[df3[i]==98])
print(check) # 제대로 변경됨 확인!
# Out:
# [Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns]]

# %% [markdown]
# #### 사망여부 변수 추가하기!
#
# - date_died = 99-99-9999인 사람은 DEATH=0 (생존)
# - date_died 에 날짜가 입력되어 있는 사람은 DEATH=1 (사망)

# %%
df4 = df3.copy()
df4['DEATH'] = np.where(df4['date_died']=='9999-99-99', 0, 1)

# %%
df4[df4.date_died == '9999-99-99'].DEATH
# Out:
# 0         0
# 1         0
# 4         0
# 5         0
# 6         0
#          ..
# 121907    0
# 121908    0
# 121909    0
# 121911    0
# 121912    0
# Name: DEATH, Length: 88993, dtype: int32

# %%
df4[df4.date_died != '9999-99-99'].DEATH
# Out:
# 2         1
# 3         1
# 12        1
# 14        1
# 16        1
#          ..
# 121899    1
# 121901    1
# 121902    1
# 121906    1
# 121910    1
# Name: DEATH, Length: 32426, dtype: int32

# %% [markdown]
# #### 생존자 사망일 Imputation 하기!
#
# - Entry date, symptom date, death date 중 가장 마지막 날짜로 생존자 사망일 imputation
# - 원래 date_died 변수는 손대지 않고 last_date로 새 변수 만들어서 채워넣기!

# %%
entry = df4[df4.entry_date != '9999-99-99'].entry_date
sym = df4[df4.date_symptoms != '9999-99-99'].date_symptoms
dth = df4[df4.date_died != '9999-99-99'].date_died

# %%
tot_date = pd.concat([entry, sym, dth], ignore_index=True)
tot_date
# Out:
# 0         06-04-2020
# 1         17-04-2020
# 2         13-04-2020
# 3         16-04-2020
# 4         22-04-2020
#              ...
# 275259    13-05-2020
# 275260    19-06-2020
# 275261    05-06-2020
# 275262    14-06-2020
# 275263    13-05-2020
# Length: 275264, dtype: object

# %%
tot_date = pd.to_datetime(tot_date, format = '%d-%m-%Y')
tot_date
# Out:
# 0        2020-05-31
# 1        2020-05-31
# 2        2020-05-31
# 3        2020-05-31
# 4        2020-05-31
#             ...
# 275259   2020-01-01
# 275260   2020-01-01
# 275261   2020-01-01
# 275262   2020-01-01
# 275263   2020-01-01
# Length: 275264, dtype: datetime64[ns]

# %%
tot_date.max() # 가장 최근날짜 2020-06-29
# Out:
# Timestamp('2020-06-29 00:00:00')

# %%
df5 = df4.copy()
df5['last_date'] = df4['date_died'].apply(lambda x : '29-06-2020' if x == '9999-99-99' else x)

# %%
df5[df5.DEATH == 0].last_date
# Out:
# 0         29-06-2020
# 1         29-06-2020
# 4         29-06-2020
# 5         29-06-2020
# 6         29-06-2020
#              ...
# 121907    29-06-2020
# 121908    29-06-2020
# 121909    29-06-2020
# 121911    29-06-2020
# 121912    29-06-2020
# Name: last_date, Length: 88993, dtype: object
